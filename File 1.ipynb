# %%
#FILE 1
import openpyxl as px
import openpyxl
import numpy as np
import warnings
import nltk

# %%
myfile = open("MANAGEMENT'S DISCUSSION AND ANALYSIS.txt")

# %%
print(myfile)
# Out:
# <_io.TextIOWrapper name="MANAGEMENT'S DISCUSSION AND ANALYSIS.txt" mode='r' encoding='cp1252'>

# %%
print(myfile.read())
# Out:
# ITEM 7. MANAGEMENT'S DISCUSSION AND ANALYSIS OF FINANCIAL CONDITION AND RESULTS
#         OF OPERATION
#
#
# YEAR ENDED DECEMBER 28, 1997 COMPARED TO THE YEAR ENDED DECEMBER 29, 1996
#
#
#      In November 1996, the Company initiated a major restructuring and growth
# plan designed to substantially reduce its cost structure and grow the business
# in order to restore higher levels of profitability for the Company. By July
# 1997, the Company completed the major phases of the restructuring plan. The
# $225.0 million of annualized cost savings anticipated from the restructuring
# results primarily from the consolidation of administrative functions within the
# Company, the rationalization of manufacturing and warehouse facilities
# (including a reduction in the number of production facilities from 26 to 8 and
# warehouses from 61 to 18), the elimination of over 6,000 positions (including
# 3,300 from the divestiture of non-core businesses described below and
# ...

# %%
print(myfile.readlines())
# Out:
# []

# %%
file_content = open("MANAGEMENT'S DISCUSSION AND ANALYSIS.txt").read()

# %%
#NUMBER OF LINES
Counter = 0
  
CoList = file_content.split("\n") 
  
for i in CoList: 
    if i: 
        Counter += 1
          
print("This is the number of lines in the file") 
print(Counter)
# Out:
# This is the number of lines in the file
# 360

# %%
Number_of_sentences_in_text_file = Counter

# %%
#NUMBER OF WORDS
words = file_content.split()
Total_Words_after_cleaning = len(words)
print('Number of words in text file :', len(words))
# Out:
# Number of words in text file : 3676

# %%
Number_of_words_in_text_file = len(words)

# %%
#SENTENCE TOKENIZATION
import nltk.data
import codecs
import os

doc = codecs.open('MANAGEMENT'S DISCUSSION AND ANALYSIS.txt', 'r', 'utf-8')
content = doc.read()

tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')

print ('\n-----\n'.join(tokenizer.tokenize(content)))
# Out:
#   File "<ipython-input-104-869f4b73310b>", line 6
#     doc = codecs.open('MANAGEMENT'S DISCUSSION AND ANALYSIS.txt', 'r', 'utf-8')
#                                   ^
# SyntaxError: invalid syntax

# %%
#WORD TOKENIZATION
import nltk
file_content = open("MANAGEMENT'S DISCUSSION AND ANALYSIS.txt").read()
tokens = nltk.word_tokenize(file_content)
print(tokens)
# Out:
# ['ITEM', '7', '.', 'MANAGEMENT', "'S", 'DISCUSSION', 'AND', 'ANALYSIS', 'OF', 'FINANCIAL', 'CONDITION', 'AND', 'RESULTS', 'OF', 'OPERATION', 'YEAR', 'ENDED', 'DECEMBER', '28', ',', '1997', 'COMPARED', 'TO', 'THE', 'YEAR', 'ENDED', 'DECEMBER', '29', ',', '1996', 'In', 'November', '1996', ',', 'the', 'Company', 'initiated', 'a', 'major', 'restructuring', 'and', 'growth', 'plan', 'designed', 'to', 'substantially', 'reduce', 'its', 'cost', 'structure', 'and', 'grow', 'the', 'business', 'in', 'order', 'to', 'restore', 'higher', 'levels', 'of', 'profitability', 'for', 'the', 'Company', '.', 'By', 'July', '1997', ',', 'the', 'Company', 'completed', 'the', 'major', 'phases', 'of', 'the', 'restructuring', 'plan', '.', 'The', '$', '225.0', 'million', 'of', 'annualized', 'cost', 'savings', 'anticipated', 'from', 'the', 'restructuring', 'results', 'primarily', 'from', 'the', 'consolidation', 'of', 'administrative', 'functions', 'within', 'the', 'Company', ',', 'the', 'rationalization', 'of', 'ma
# ...

# %%
#FREQUENCY DISTRIBUTION
from nltk.probability import FreqDist
fdist = FreqDist(tokens)
print(fdist)
# Out:
# <FreqDist with 1007 samples and 4242 outcomes>

# %%
import matplotlib.pyplot as plt
fdist.plot(30,cumulative=False)
plt.show()

# %%
#REMOVING STOPWORDS
from nltk.corpus import stopwords
stop_words=set(stopwords.words("english"))
filtered_sent=[]
for w in tokens:
    if w not in stop_words:
        filtered_sent.append(w)
print("Tokenized Sentence:",tokens)
print("Filterd Sentence:",filtered_sent)
# Out:
# Tokenized Sentence: ['ITEM', '7', '.', 'MANAGEMENT', "'S", 'DISCUSSION', 'AND', 'ANALYSIS', 'OF', 'FINANCIAL', 'CONDITION', 'AND', 'RESULTS', 'OF', 'OPERATION', 'YEAR', 'ENDED', 'DECEMBER', '28', ',', '1997', 'COMPARED', 'TO', 'THE', 'YEAR', 'ENDED', 'DECEMBER', '29', ',', '1996', 'In', 'November', '1996', ',', 'the', 'Company', 'initiated', 'a', 'major', 'restructuring', 'and', 'growth', 'plan', 'designed', 'to', 'substantially', 'reduce', 'its', 'cost', 'structure', 'and', 'grow', 'the', 'business', 'in', 'order', 'to', 'restore', 'higher', 'levels', 'of', 'profitability', 'for', 'the', 'Company', '.', 'By', 'July', '1997', ',', 'the', 'Company', 'completed', 'the', 'major', 'phases', 'of', 'the', 'restructuring', 'plan', '.', 'The', '$', '225.0', 'million', 'of', 'annualized', 'cost', 'savings', 'anticipated', 'from', 'the', 'restructuring', 'results', 'primarily', 'from', 'the', 'consolidation', 'of', 'administrative', 'functions', 'within', 'the', 'Company', ',', 'the', 'rationa
# ...

# %%
#STEMMING
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize

ps = PorterStemmer()

stemmed_words=[]
for w in filtered_sent:
    stemmed_words.append(ps.stem(w))

print("Filtered Sentence:",filtered_sent)
print("Stemmed Sentence:",stemmed_words)
# Out:
# Filtered Sentence: ['--', '--', '-BEGIN', 'PRIVACY-ENHANCED', 'MESSAGE', '--', '--', '-', 'Proc-Type', ':', '2001', ',', 'MIC-CLEAR', 'Originator-Name', ':', 'webmaster', '@', 'www.sec.gov', 'Originator-Key-Asymmetric', ':', 'MFgwCgYEVQgBAQICAf8DSgAwRwJAW2sNKK9AVtBzYZmr6aGjlWyK3XmZv3dTINen', 'TWSM7vrzLADbmYQaionwg5sDW3P6oaM5D3tdezXMm7z1T+B+twIDAQAB', 'MIC-Info', ':', 'RSA-MD5', ',', 'RSA', ',', 'EvPdKfnjzBIjWkEk2RgNCk1/52qXomHpN+LDwL/XTT/XBuAzk70AYYrsxlQbyiqr', 'V5559QRyTgPe9PfVt0db9Q==', '<', 'SEC-DOCUMENT', '>', '0000950170-98-000413.txt', ':', '19980309', '<', 'SEC-HEADER', '>', '0000950170-98-000413.hdr.sgml', ':', '19980309', 'ACCESSION', 'NUMBER', ':', '0000950170-98-000413', 'CONFORMED', 'SUBMISSION', 'TYPE', ':', '10-K405', 'PUBLIC', 'DOCUMENT', 'COUNT', ':', '21', 'CONFORMED', 'PERIOD', 'OF', 'REPORT', ':', '19971228', 'FILED', 'AS', 'OF', 'DATE', ':', '19980306', 'SROS', ':', 'NYSE', 'FILER', ':', 'COMPANY', 'DATA', ':', 'COMPANY', 'CONFORMED', 'NAME', ':', 'SUNBEAM', 'CORP
# ...

# %%
#Lexicon Normalization
#performing stemming and Lemmatization

from nltk.stem.wordnet import WordNetLemmatizer
lem = WordNetLemmatizer()

from nltk.stem.porter import PorterStemmer
stem = PorterStemmer()
for w in filtered_sent:
    word = w
    print("Lemmatized Word:",lem.lemmatize(word,"v"))
    print("Stemmed Word:",stem.stem(word))
# Out:
# Lemmatized Word: ITEM
# Stemmed Word: item
# Lemmatized Word: 7
# Stemmed Word: 7
# Lemmatized Word: .
# Stemmed Word: .
# Lemmatized Word: MANAGEMENT
# Stemmed Word: manag
# Lemmatized Word: 'S
# Stemmed Word: 'S
# Lemmatized Word: DISCUSSION
# Stemmed Word: discuss
# Lemmatized Word: AND
# Stemmed Word: and
# Lemmatized Word: ANALYSIS
# Stemmed Word: analysi
# Lemmatized Word: OF
# Stemmed Word: OF
# Lemmatized Word: FINANCIAL
# Stemmed Word: financi
# Lemmatized Word: CONDITION
# Stemmed Word: condit
# Lemmatized Word: AND
# Stemmed Word: and
# Lemmatized Word: RESULTS
# Stemmed Word: result
# Lemmatized Word: OF
# Stemmed Word: OF
# Lemmatized Word: OPERATION
# Stemmed Word: oper
# Lemmatized Word: YEAR
# Stemmed Word: year
# Lemmatized Word: ENDED
# Stemmed Word: end
# Lemmatized Word: DECEMBER
# Stemmed Word: decemb
# Lemmatized Word: 28
# Stemmed Word: 28
# Lemmatized Word: ,
# Stemmed Word: ,
# Lemmatized Word: 1997
# Stemmed Word: 1997
# Lemmatized Word: COMPARED
# ...

# %%
import nltk
nltk.download('opinion_lexicon')
# Out:
# [nltk_data] Downloading package opinion_lexicon to C:\Users\Aastha
# [nltk_data]     singh\AppData\Roaming\nltk_data...
# [nltk_data]   Package opinion_lexicon is already up-to-date!
# True

# %%
from nltk.corpus import opinion_lexicon

# %%
pos_list=set(opinion_lexicon.positive())
neg_list=set(opinion_lexicon.negative())

# %%
file_content = open("MANAGEMENT'S DISCUSSION AND ANALYSIS.txt").read().split('\n')
positive_dictionary= []
negative_dictionary = []
for line in file_content:
    tokens = nltk.word_tokenize(line)
    for word in tokens:
        if word.lower() in pos_list:
            positive_dictionary.append(word)
        elif word.lower() in neg_list:
            negative_dictionary.append(word)
print(positive_dictionary)
# Out:
# ['restructuring', 'restructuring', 'savings', 'restructuring', 'savings', 'restructuring', 'Comfort', 'improved', 'top', 'improved', 'exceeded', 'Comfort', 'improve', 'important', 'Comfort', 'improved', 'benefit', 'savings', 'enhancement', 'restructuring', 'refinement', 'improving', 'benefits', 'refinement', 'refinement', 'improve', 'improvements', 'improved', 'awards', 'improved', 'effective', 'outstanding', 'benefits', 'benefits', 'Restructuring', 'restructuring', 'restructuring', 'Restructuring', 'restructuring', 'stable', 'restructuring', 'awards', 'effective', 'benefits', 'awards', 'benefits', 'restructuring', 'support', 'improve', 'restructuring', 'restructuring', 'support', 'available', 'restructuring', 'comprehensive', 'well', 'sufficient', 'support', 'COMPREHENSIVE', 'compliant', 'compliant']

# %%
print(negative_dictionary)
# Out:
# ['elimination', 'elimination', 'discontinued', 'declines', 'suffered', 'inability', 'fell', 'gross', 'suffered', 'poor', 'gross', 'restricted', 'bad', 'debt', 'loss', 'loss', 'loss', 'discontinued', 'discontinued', 'loss', 'loss', 'Discontinued', 'loss', 'discontinued', 'loss', 'loss', 'loss', 'decline', 'instability', 'suffered', 'decline', 'gross', 'inflated', 'restricted', 'losses', 'restricted', 'discontinued', 'discontinued', 'gross', 'bad', 'debt', 'risk', 'insignificant', 'limited', 'debt', 'discontinued', 'discontinued', 'debt', 'debt', 'adverse', 'debt', 'debt', 'debt', 'debt', 'debt', 'debt', 'issue', 'issues', 'adverse', 'CAUTIONARY', 'Cautionary', 'Cautionary']

# %%
positive_score = 0
for item in positive_dictionary:
    positive_score = positive_score + 1
print(positive_score)
# Out:
# 61

# %%
negative_score = 0
for item in negative_dictionary:
    negative_score = negative_score + 1
print(negative_score)
# Out:
# 62

# %%
polarity_score = (positive_score - negative_score)/ ((positive_score + negative_score) + 0.000001)
print(polarity_score)
# Out:
# -0.008130081234714787

# %%
subjectivity_score = (positive_score + negative_score)/ ((Total_Words_after_cleaning) + 0.000001)
print(subjectivity_score)
# Out:
# 0.033460282907110915

# %%
#Analysis of Readability

# %%
Average_Sentence_Length = Number_of_words_in_text_file/Number_of_sentences_in_text_file
print(Average_Sentence_Length)
# Out:
# 10.21111111111111

# %%
import spacy 
from textstat.textstat import textstatistics, legacy_round

# %%
#COMPLEX WORD COUNT
from textstat import syllable_count
file_content = open("0000950170-98-000413.txt").read()
words = file_content.split()
complex_words = [] 

for word in words: 
    syllables = textstatistics().syllable_count(word)
    if syllables >= 2: 
        complex_words.append(word) 
print(len(complex_words))
# Out:
# 67524

# %%
Percentage_of_Complex_words = len(complex_words) / Number_of_words_in_text_file
print(Percentage_of_Complex_words )
# Out:
# 18.368879216539717

# %%
Fog_Index = 0.4 * (Average_Sentence_Length + Percentage_of_Complex_words)
print(Fog_Index)
# Out:
# 11.43199613106033

# %%
import openpyxl
import pandas as pd
uncertainty_dictionary= openpyxl.load_workbook('uncertainty_dictionary.xlsx')
constraining_dictionary= openpyxl.load_workbook('constraining_dictionary.xlsx')

# %%
print(uncertainty_dictionary)

# %%
#UNCERTAINTY
# Reading an excel file using Python 
import xlrd 
# To open Workbook 
wb = xlrd.open_workbook('uncertainty_dictionary.xlsx') 
sheet = wb.sheet_by_index(0) 
uncertainty_dictionary = []
# For row 0 and column 0 
for i in range(sheet.nrows):
    print(sheet.cell_value(i, 0).lower()) 
    if sheet.cell_value(i, 0).lower() not in uncertainty_dictionary:
        uncertainty_dictionary.append(sheet.cell_value(i, 0).lower())
print(len(uncertainty_dictionary))
# Out:
# word
# abeyance
# abeyances
# almost
# alteration
# alterations
# ambiguities
# ambiguity
# ambiguous
# anomalies
# anomalous
# anomalously
# anomaly
# anticipate
# anticipated
# anticipates
# anticipating
# anticipation
# anticipations
# apparent
# apparently
# appear
# appeared
# appearing
# appears
# approximate
# approximated
# approximately
# approximates
# approximating
# approximation
# approximations
# arbitrarily
# arbitrariness
# arbitrary
# assume
# assumed
# assumes
# assuming
# assumption
# assumptions
# believe
# believed
# believes
# believing
# cautious
# cautiously
# cautiousness
# clarification
# clarifications
# conceivable
# conceivably
# conditional
# conditionally
# confuses
# confusing
# confusingly
# confusion
# contingencies
# contingency
# contingent
# contingently
# contingents
# could
# crossroad
# crossroads
# depend
# depended
# dependence
# dependencies
# dependency
# dependent
# depending
# depends
# destabilizing
# deviate
# deviated
# deviates
# ...

# %%
for word in words:
    if word in uncertainty_dictionary:
         uncertainty = uncertainty + 1
print(uncertainty)
# Out:
# 862

# %%
#CONSTRAINING
# To open Workbook 
import xlrd
wb = xlrd.open_workbook('constraining_dictionary.xlsx') 
sheet = wb.sheet_by_index(0) 
constraining_dictionary = []
# For row 0 and column 0 
for i in range(sheet.nrows):
    print(sheet.cell_value(i, 0).lower()) 
    if sheet.cell_value(i, 0).lower() not in constraining_dictionary:
        constraining_dictionary.append(sheet.cell_value(i, 0).lower())
print(len(constraining_dictionary))
# Out:
# word
# abide
# abiding
# bound
# bounded
# commit
# commitment
# commitments
# commits
# committed
# committing
# compel
# compelled
# compelling
# compels
# comply
# compulsion
# compulsory
# confine
# confined
# confinement
# confines
# confining
# constrain
# constrained
# constraining
# constrains
# constraint
# constraints
# covenant
# covenanted
# covenanting
# covenants
# depend
# dependance
# dependances
# dependant
# dependencies
# dependent
# depending
# depends
# dictate
# dictated
# dictates
# dictating
# directive
# directives
# earmark
# earmarked
# earmarking
# earmarks
# encumber
# encumbered
# encumbering
# encumbers
# encumbrance
# encumbrances
# entail
# entailed
# entailing
# entails
# entrench
# entrenched
# escrow
# escrowed
# escrows
# forbade
# forbid
# forbidden
# forbidding
# forbids
# impair
# impaired
# impairing
# impairment
# impairments
# impairs
# impose
# imposed
# imposes
# imposing
# imposition
# impositions
# indebted
# inhibit
# inhibited
# ...

# %%
for word in words:
    if word in constraining_dictionary:
         constraining = constraining + 1
print(constraining)
# Out:
# 2114
